# %%
import pandas as pd

# %%
df=pd.read_csv('CricketTestMatchData.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 59   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 60  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 61  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 62    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 63   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# 1   64.38    5   4   -   123  23
# 2   55.68    5   4   2   186   5
# 3   54.48    7  11   1  246+  11
# 4   56.00   10   5   2  104+   1
# ..    ...  ...  ..  ..   ...  ..
# 59  49.16   15  33   4  525+  23
# 60  59.67   27  38  11  1165  24
# 61  44.77    7   6   1  119+   0
# 62  60.02    6  13   4  241+  5+
# 63  25.59    1  10   2   53+   0
#
# [64 rows x 15 columns]

# %%
df = df.rename(columns = {'Mat':'Matches','NO':'Not_Outs','HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'Batting_Strike_Rate'})

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    PHKD Mendis (SL)  2022-2025       12    21         2  1184
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 59   KD Walters (AUS)  1965-1981       74   125        14  5357
# 60  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 61  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 62    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 63   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# 1                182*  62.31        1839                64.38    5   4   -
# 2                269*  61.87        2667                55.68    5   4   2
# 3                 274  60.97       1707+                54.48    7  11   1
# 4                270*  60.83        416+                56.00   10   5   2
# ..                ...    ...         ...                  ...  ...  ..  ..
# 59                250  48.26       8662+                49.16   15  33   4
# 60                277  48.25       15525                59.67   27  38  11
# 61                266  48.22       3118+                44.77    7   6   1
# 62                232  48.21       3217+                60.02    6  13   4
# 63                127  48.00       2110+                25.59    1  10   2
#
#       4s  6s
# 0   626+   6
# 1    123  23
# 2    186   5
# 3   246+  11
# 4   104+   1
# ..   ...  ..
# 59  525+  23
# 60  1165  24
# 61  119+   0
# 62  241+  5+
# 63   53+   0
#
# [64 rows x 15 columns]

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 16       CL Walcott (WI)  1948-1960       44    74         7  3798
# 17       CL Walcott (WI)  1948-1960       44    74         7  3798
# 56  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8                 207  58.61         NaN                  NaN   15  19  6
# 16                220  56.68         NaN                  NaN   15  14  1
# 17                220  56.68         NaN                  NaN   15  14  1
# 56               144*  48.79         NaN                  NaN    5   6  3
#
#       4s  6s
# 8   258+   2
# 16  107+  11
# 17  107+  11
# 56   51+   0

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player']=='ED Weekes (WI)']
# Out:
#            Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8                207  58.61           0                  0.0   15  19  6
#
#      4s 6s
# 8  258+  2

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# Length: 64, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 17  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 12               365*  57.78       4063+                53.58   26  30  12
# 17                220  56.68           0                 0.00   15  14   1
#
#       4s   6s
# 12  593+  32+
# 17  107+   11

# %%
df[df['Player'].isin(['GS Sobers (WI)','CL Walcott (WI)'])]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 11   GS Sobers (WI)  1954-1974       93   160        21  8032
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 16  CL Walcott (WI)  1948-1960       44    74         7  3798
# 17  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 11               365*  57.78       4063+                53.58   26  30  12
# 12               365*  57.78       4063+                53.58   26  30  12
# 16                220  56.68           0                 0.00   15  14   1
# 17                220  56.68           0                 0.00   15  14   1
#
#       4s   6s
# 11  593+  32+
# 12  593+  32+
# 16  107+   11
# 17  107+   11

# %%
df=df.drop_duplicates()

# %%
df[df['Player'].isin(['GS Sobers (WI)','CL Walcott (WI)'])]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 11   GS Sobers (WI)  1954-1974       93   160        21  8032
# 16  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 11               365*  57.78       4063+                53.58   26  30  12
# 16                220  56.68           0                 0.00   15  14   1
#
#       4s   6s
# 11  593+  32+
# 16  107+   11

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2025]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 59    [1965, 1981]
# 60    [2002, 2014]
# 61    [1924, 1934]
# 62    [1930, 1938]
# 63    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Rockie_Year']= df['Span'].str.split(pat = '-').str[0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Final_Year']= df['Span'].str.split(pat = '-').str[1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Final_Year']
# Out:
# 0     1948
# 1     2025
# 2     2016
# 3     1970
# 4     1954
#       ...
# 59    1981
# 60    2014
# 61    1934
# 62    1938
# 63    1934
# Name: Final_Year, Length: 62, dtype: object

# %%
df = df.drop(['Span'],axis = 1)

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1      [PHKD Mendis , SL)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 59     [KD Walters , AUS)]
# 60    [GC Smith , ICC/SA)]
# 61    [WH Ponsford , AUS)]
# 62      [SJ McCabe , AUS)]
# 63     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
 df['Country']= df['Player'].str.split(pat = '(').str[1]

# %%
 df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
 df['Player']= df['Player'].str.split(pat = '(').str[0]

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int32
# 4s                       int32
# 6s                       int32
# Rockie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
 df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df['0'] = df['0'].str.split(pat = '+').str[0]

# %%
df[df['0']=='-']
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rockie_Year, Final_Year, Country]
# Index: []

# %%
df['0'] = df['0'].replace('-', 0)

# %%
df['0'] = df['0'].astype('int')

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df['4s'] = df['4s'].astype('int')

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]
df['6s'] = df['6s'].astype('int')

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                 334  99.94
# 1   PHKD Mendis        12    21         2  1184                 182  62.31
# 2      AC Voges        20    31         7  1485                 269  61.87
# 3    RG Pollock        23    41         4  2256                 274  60.97
# 4    GA Headley        22    40         4  2190                 270  60.83
# ..           ...      ...   ...       ...   ...                 ...    ...
# 59   KD Walters        74   125        14  5357                 250  48.26
# 60     GC Smith       117   205        13  9265                 277  48.25
# 61  WH Ponsford        29    48         4  2122                 266  48.22
# 62    SJ McCabe        39    62         5  2748                 232  48.21
# 63   DR Jardine        22    33         6  1296                 127  48.00
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  Rockie_Year  \
# 0          9800                58.60   29  13   7  626+   6         1928
# 1          1839                64.38    5   4   0   123  23         2022
# 2          2667                55.68    5   4   2   186   5         2015
# 3          1707                54.48    7  11   1  246+  11         1963
# 4           416                56.00   10   5   2  104+   1         1930
# ..          ...                  ...  ...  ..  ..   ...  ..          ...
# 59         8662                49.16   15  33   4  525+  23         1965
# 60        15525                59.67   27  38  11  1165  24         2002
# 61         3118                44.77    7   6   1  119+   0         1924
# 62         3217                60.02    6  13   4  241+  5+         1930
# 63         2110                25.59    1  10   2   53+   0         1928
#
#     Final_Year Country
# 0         1948     AUS
# 1         2025      SL
# 2         2016     AUS
# 3         1970      SA
# 4         1954      WI
# ..         ...     ...
# 59        1981     AUS
# 60        2014  ICC/SA
# 61        1934     AUS
# 62        1938     AUS
# 63        1934     ENG
#
# [62 rows x 17 columns]

# %%
df = df.astype({'Rockie_Year':'int','Final_Year':'int'})

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                 334  99.94
# 1   PHKD Mendis        12    21         2  1184                 182  62.31
# 2      AC Voges        20    31         7  1485                 269  61.87
# 3    RG Pollock        23    41         4  2256                 274  60.97
# 4    GA Headley        22    40         4  2190                 270  60.83
# ..           ...      ...   ...       ...   ...                 ...    ...
# 59   KD Walters        74   125        14  5357                 250  48.26
# 60     GC Smith       117   205        13  9265                 277  48.25
# 61  WH Ponsford        29    48         4  2122                 266  48.22
# 62    SJ McCabe        39    62         5  2748                 232  48.21
# 63   DR Jardine        22    33         6  1296                 127  48.00
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  Rockie_Year  \
# 0          9800                58.60   29  13   7   626   6         1928
# 1          1839                64.38    5   4   0   123  23         2022
# 2          2667                55.68    5   4   2   186   5         2015
# 3          1707                54.48    7  11   1   246  11         1963
# 4           416                56.00   10   5   2   104   1         1930
# ..          ...                  ...  ...  ..  ..   ...  ..          ...
# 59         8662                49.16   15  33   4   525  23         1965
# 60        15525                59.67   27  38  11  1165  24         2002
# 61         3118                44.77    7   6   1   119   0         1924
# 62         3217                60.02    6  13   4   241   5         1930
# 63         2110                25.59    1  10   2    53   0         1928
#
#     Final_Year Country
# 0         1948     AUS
# 1         2025      SL
# 2         2016     AUS
# 3         1970      SA
# 4         1954      WI
# ..         ...     ...
# 59        1981     AUS
# 60        2014  ICC/SA
# 61        1934     AUS
# 62        1938     AUS
# 63        1934     ENG
#
# [62 rows x 17 columns]

# %%
df['Career_Length']= df['Final_Year'] - df['Rockie_Year']

# %%
df['Career_Length'].mean()
# Out:
# 12.96774193548387

# %%
df[df['Career_Length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# 47.80186046511627

# %%
df[df['Rockie_Year'] < 1960 ]['Player'].count()
# Out:
# 23

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highinncountry').reset_index().sort_values('Highinncountry',ascending = False)
# Out:
#     Country  Highinncountry
# 5    ICC/WI             400
# 0       AUS             380
# 10       SL             374
# 11       WI             365
# 1       ENG             364
# 3   ICC/PAK             329
# 2   ICC/IND             319
# 8       PAK             313
# 9        SA             278
# 4    ICC/SA             277
# 7        NZ             251
# 6       IND             248
# 12      ZIM             232

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      21.533333  28.933333   8.933333
# ENG      13.076923  21.384615   4.461538
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      23.250000  31.500000   8.000000
# NZ       33.000000  37.000000  11.000000
# PAK      17.800000  24.200000   8.000000
# SA        9.800000  20.200000   3.400000
# SL       22.750000  34.000000   9.250000
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000

# %%
df.to_csv(r"C:\Users\16341\Desktop\CricketTestMatchData_Cleaned.csv", index=False, encoding="utf-8-sig")
